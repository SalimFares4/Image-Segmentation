# %% [markdown]
# https://www.earthdatascience.org/tutorials/visualize-digital-elevation-model-contours-matplotlib/

# %%
from osgeo import gdal
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import elevation

# %%
# !pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
from PIL import Image
filename = "C:\\Users\\salee\\Data Science Lab\\Lunar Challenge\\EXPLORE_temporary_datashare\\EXPLORE-DC-dataset-examples\\LROC\\NAC\\M101949648LE_lev2.tif"
image = Image.open(filename)
new_image = image.resize((300, 300), Image.ANTIALIAS)
# Out:
# ---------------------------------------------------------------------------
# DecompressionBombError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1428/3472490071.py in <module>
#       1 from PIL import Image
#       2 filename = "C:\\Users\\salee\\Data Science Lab\\Lunar Challenge\\EXPLORE_temporary_datashare\\EXPLORE-DC-dataset-examples\\LROC\\NAC\\M101949648LE_lev2.tif"
# ----> 3 image = Image.open(filename)
#       4 new_image = image.resize((300, 300), Image.ANTIALIAS)
#
# ~\anaconda3\envs\myenv\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3007         return None
#    3008
# -> 3009     im = _open_core(fp, filename, prefix, formats)
#    3010
#    3011     if im is None:
#
# ~\anaconda3\envs\myenv\lib\site-packages\PIL\Image.py in _open_core(fp, filename, prefix, formats)
#    2994                     fp.seek(0)
#    2995                     im = factory(fp, filename)
# ...

# %%
# filename = 'test2.tif'
gdal_data = gdal.Open(filename)
gdal_band = gdal_data.GetRasterBand(1)
nodataval = gdal_band.GetNoDataValue()

# convert to a numpy array
data_array=[]
data_array = gdal_data.ReadAsArray().astype(np.float)
# data_array

# replace missing values if necessary
if np.any(data_array == nodataval):
    data_array[data_array == nodataval] = np.nan
data_array.shape
# Out:
# C:\Users\salee\AppData\Local\Temp/ipykernel_10096/1211465001.py:9: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data_array = gdal_data.ReadAsArray().astype(np.float)
# (50109, 6309)

# %%
#Plot out data with Matplotlib's 'contour'
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111)
plt.contour(data_array, cmap = "viridis", 
            levels = list(range(0, 5000, 100)))
plt.title("Elevation Contours of Mt. Shasta")
cbar = plt.colorbar()
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
#Plot image in grayscale
plt.figure(figsize=(5,5))
plt.imshow(data_array, cmap = 'gray')
plt.colorbar()
plt.title("Mars lowres 'Hillshade.tif' ")
plt.show()


#Plot a contour graph
plt.figure(figsize=(5,5))
plt.title("Elevation Contour map")
plt.contourf(data_array)
plt.colorbar()
plt.gca().set_aspect('equal')
plt.gca().invert_yaxis()
plt.show()

# %%
#Plot our data with Matplotlib's 'contourf'
# fig = plt.figure(figsize = (12, 8))
# ax = fig.add_subplot(111)
# plt.contourf(data_array, cmap = "viridis", 
#             levels = list(range(0, 5000, 500)))
# plt.title("Elevation Contours of Mt. Shasta")
# cbar = plt.colorbar()
# plt.gca().set_aspect('equal', adjustable='box')
# plt.show()

# %%
# filename = 'test2.tif'
# plt.rcParams["figure.figsize"] = [12, 8]
# plt.rcParams["figure.autolayout"] = True
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# z, x, y = data_array.nonzero()
# ax.scatter(x, y, z, c=z, alpha=1)
# plt.show()
